# %%
from metrics import *
from vizualize import *
from test import *
img_1, img_2, mask, res = create_reference(70)
vizualize(mask, 'Mask', save=False)

# %%
crop_1 = create_crop(img_1, 70)
crop_2 = create_crop(img_2, 70)
vizualize(crop_2, 'Crop 2', save=False)

# %%
print('Correct result: ', res, '\nMAMSE: ', MAMSE(img_1, img_2, mask), '\nMSE crop: ', 
      MAMSE(crop_1, crop_2, np.ones(np.shape(crop_1))))
# Out:
# Correct result:  5.102040816326531e-05
# MAMSE:  5.102040816326531e-05
# MSE crop:  5.102040816326531e-05
